# %% [markdown]
# <a href="https://colab.research.google.com/github/Richupatel2109/LGMVIP--DataScience-task-3/blob/main/using_python.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## BEGINNER Level (Task-3)
# # Image to pencil sketch using python

# %%
import cv2
print(cv2.__version__)
import matplotlib.pyplot as plt
# Out:
# 4.1.2

# %%
img_path = r"/content/drive/MyDrive/hd-wallpaper-729512.jpg"

# %%
img = cv2.imread(img_path)
img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
plt.figure(figsize=(8,6))
plt.imshow(img)
plt.axis('off')
plt.title('original image')
plt.show()

# %%
gray_image = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
plt.figure(figsize=(8,6))
plt.imshow(gray_image,cmap='gray')
plt.axis('off')
plt.title('Gray image')
plt.show()

# %%
image_invert = cv2.bitwise_not(gray_image)
plt.figure(figsize=(8,6))
plt.imshow(image_invert,cmap='gray')
plt.axis('off')
plt.title('inverted Image')
plt.show()

# %%
Gsn_image = cv2.GaussianBlur(image_invert,(21,21),sigmaX=0,sigmaY=0)
plt.figure(figsize=(8,6))
plt.imshow(Gsn_image,cmap='gray')
plt.axis('off')
plt.title('Gaussian Blur Image')
plt.show()

# %%
pencil_sketch = cv2.divide(gray_image,255 - Gsn_image, scale = 255)
plt.figure(figsize=(10,8))
plt.imshow(pencil_sketch,cmap='gray')
plt.axis('off')
plt.title('Pencil_Sketch Image')
plt.show()
